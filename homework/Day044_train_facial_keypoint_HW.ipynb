# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_37 (Conv2D)           (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_28 (Dense)             (None, 512)               1049088
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 4s 3ms/step - loss: 0.0057 - val_loss: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00215, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 0.0015 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00215 to 0.00189, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00189 to 0.00186, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00186 to 0.00181, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 9.8644e-04 - val_loss: 0.0017
#
# Epoch 00005: val_loss improved from 0.00181 to 0.00170, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.4838e-04 - val_loss: 0.0016
#
# Epoch 00006: val_loss improved from 0.00170 to 0.00161, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 7.2290e-04 - val_loss: 0.0015
#
# Epoch 00007: val_loss improved from 0.00161 to 0.00147, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 6.4969e-04 - val_loss: 0.0013
#
# Epoch 00008: val_loss improved from 0.00147 to 0.00130, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 5.7432e-04 - val_loss: 0.0012
#
# Epoch 00009: val_loss improved from 0.00130 to 0.00120, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 5.1990e-04 - val_loss: 0.0011
#
# Epoch 00010: val_loss improved from 0.00120 to 0.00112, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 4.7897e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00112 to 0.00106, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 4.3599e-04 - val_loss: 0.0010
#
# Epoch 00012: val_loss improved from 0.00106 to 0.00102, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 4.1562e-04 - val_loss: 9.7362e-04
#
# Epoch 00013: val_loss improved from 0.00102 to 0.00097, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 3.7734e-04 - val_loss: 9.7681e-04
#
# Epoch 00014: val_loss did not improve from 0.00097
# Epoch 15/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 3.6937e-04 - val_loss: 9.0025e-04
#
# Epoch 00015: val_loss improved from 0.00097 to 0.00090, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 3.4512e-04 - val_loss: 9.1773e-04
#
# Epoch 00016: val_loss did not improve from 0.00090
# Epoch 17/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 3.2983e-04 - val_loss: 8.5819e-04
#
# Epoch 00017: val_loss improved from 0.00090 to 0.00086, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 3.1924e-04 - val_loss: 8.5609e-04
#
# Epoch 00018: val_loss improved from 0.00086 to 0.00086, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 3.1328e-04 - val_loss: 8.6651e-04
#
# Epoch 00019: val_loss did not improve from 0.00086
# Epoch 20/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 3.0313e-04 - val_loss: 8.6465e-04
#
# Epoch 00020: val_loss did not improve from 0.00086
# Epoch 21/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 2.8419e-04 - val_loss: 8.6056e-04
#
# Epoch 00021: val_loss did not improve from 0.00086
# Epoch 22/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 2.8616e-04 - val_loss: 8.3238e-04
#
# Epoch 00022: val_loss improved from 0.00086 to 0.00083, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 2.7098e-04 - val_loss: 8.8374e-04
#
# Epoch 00023: val_loss did not improve from 0.00083
# Epoch 24/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 2.6140e-04 - val_loss: 8.4501e-04
#
# Epoch 00024: val_loss did not improve from 0.00083
# Epoch 25/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 2.5349e-04 - val_loss: 8.2888e-04
#
# Epoch 00025: val_loss improved from 0.00083 to 0.00083, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 2.5270e-04 - val_loss: 8.2277e-04
#
# Epoch 00026: val_loss improved from 0.00083 to 0.00082, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 2.4905e-04 - val_loss: 7.8571e-04
#
# Epoch 00027: val_loss improved from 0.00082 to 0.00079, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 2.4574e-04 - val_loss: 8.1260e-04
#
# Epoch 00028: val_loss did not improve from 0.00079
# Epoch 29/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 2.3666e-04 - val_loss: 8.0692e-04
#
# Epoch 00029: val_loss did not improve from 0.00079
# Epoch 30/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 2.3064e-04 - val_loss: 8.0350e-04
#
# Epoch 00030: val_loss did not improve from 0.00079
# Epoch 31/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 2.2949e-04 - val_loss: 7.7533e-04
#
# Epoch 00031: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 2.3062e-04 - val_loss: 7.8515e-04
#
# Epoch 00032: val_loss did not improve from 0.00078
# Epoch 33/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 2.2011e-04 - val_loss: 7.7742e-04
#
# Epoch 00033: val_loss did not improve from 0.00078
# Epoch 34/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 2.1458e-04 - val_loss: 8.0362e-04
#
# Epoch 00034: val_loss did not improve from 0.00078
# Epoch 35/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 2.0789e-04 - val_loss: 8.0656e-04
#
# Epoch 00035: val_loss did not improve from 0.00078
# Epoch 36/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 2.0260e-04 - val_loss: 7.9232e-04
#
# Epoch 00036: val_loss did not improve from 0.00078
# Epoch 37/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.9697e-04 - val_loss: 7.4555e-04
#
# Epoch 00037: val_loss improved from 0.00078 to 0.00075, saving model to best_weights.h5
# Epoch 38/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.9627e-04 - val_loss: 7.7942e-04
#
# Epoch 00038: val_loss did not improve from 0.00075
# Epoch 39/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.9434e-04 - val_loss: 7.6272e-04
#
# Epoch 00039: val_loss did not improve from 0.00075
# Epoch 40/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.9489e-04 - val_loss: 7.5324e-04
#
# Epoch 00040: val_loss did not improve from 0.00075
# Epoch 41/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.9870e-04 - val_loss: 7.6715e-04
#
# Epoch 00041: val_loss did not improve from 0.00075
# Epoch 42/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.8991e-04 - val_loss: 7.7219e-04
#
# Epoch 00042: val_loss did not improve from 0.00075
# Epoch 43/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.8518e-04 - val_loss: 7.8681e-04
#
# Epoch 00043: val_loss did not improve from 0.00075
# Epoch 44/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.8360e-04 - val_loss: 7.6833e-04
#
# Epoch 00044: val_loss did not improve from 0.00075
# Epoch 45/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.8331e-04 - val_loss: 7.7332e-04
#
# Epoch 00045: val_loss did not improve from 0.00075
# Epoch 46/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.7995e-04 - val_loss: 7.5263e-04
#
# Epoch 00046: val_loss did not improve from 0.00075
# Epoch 47/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.7889e-04 - val_loss: 8.4823e-04
#
# Epoch 00047: val_loss did not improve from 0.00075
# Epoch 48/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.8841e-04 - val_loss: 8.2367e-04
#
# Epoch 00048: val_loss did not improve from 0.00075
# Epoch 49/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.7569e-04 - val_loss: 7.8366e-04
#
# Epoch 00049: val_loss did not improve from 0.00075
# Epoch 50/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.7700e-04 - val_loss: 7.6312e-04
#
# Epoch 00050: val_loss did not improve from 0.00075
# Epoch 51/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.6492e-04 - val_loss: 7.3603e-04
#
# Epoch 00051: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 52/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.6586e-04 - val_loss: 7.8140e-04
#
# Epoch 00052: val_loss did not improve from 0.00074
# Epoch 53/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.6503e-04 - val_loss: 7.7238e-04
#
# Epoch 00053: val_loss did not improve from 0.00074
# Epoch 54/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.6408e-04 - val_loss: 8.0161e-04
#
# Epoch 00054: val_loss did not improve from 0.00074
# Epoch 55/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.5930e-04 - val_loss: 7.7017e-04
#
# Epoch 00055: val_loss did not improve from 0.00074
# Epoch 56/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.5732e-04 - val_loss: 7.7722e-04
#
# Epoch 00056: val_loss did not improve from 0.00074
# Epoch 57/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.5513e-04 - val_loss: 7.6683e-04
#
# Epoch 00057: val_loss did not improve from 0.00074
# Epoch 58/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.5573e-04 - val_loss: 7.7477e-04
#
# Epoch 00058: val_loss did not improve from 0.00074
# Epoch 59/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.5468e-04 - val_loss: 7.5974e-04
#
# Epoch 00059: val_loss did not improve from 0.00074
# Epoch 60/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.5348e-04 - val_loss: 7.4886e-04
#
# Epoch 00060: val_loss did not improve from 0.00074
# Epoch 61/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.5025e-04 - val_loss: 7.6599e-04
#
# Epoch 00061: val_loss did not improve from 0.00074
# Epoch 62/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.4692e-04 - val_loss: 7.6766e-04
#
# Epoch 00062: val_loss did not improve from 0.00074
# Epoch 63/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.4415e-04 - val_loss: 7.6487e-04
#
# Epoch 00063: val_loss did not improve from 0.00074
# Epoch 64/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.4170e-04 - val_loss: 7.8799e-04
#
# Epoch 00064: val_loss did not improve from 0.00074
# Epoch 65/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.4522e-04 - val_loss: 7.5399e-04
#
# Epoch 00065: val_loss did not improve from 0.00074
# Epoch 66/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.4275e-04 - val_loss: 8.0695e-04
#
# Epoch 00066: val_loss did not improve from 0.00074
# Epoch 67/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.4393e-04 - val_loss: 7.7912e-04
#
# Epoch 00067: val_loss did not improve from 0.00074
# Epoch 68/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.5365e-04 - val_loss: 7.7259e-04
#
# Epoch 00068: val_loss did not improve from 0.00074
# Epoch 69/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.3919e-04 - val_loss: 7.7960e-04
#
# Epoch 00069: val_loss did not improve from 0.00074
# Epoch 70/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.4039e-04 - val_loss: 8.3961e-04
#
# Epoch 00070: val_loss did not improve from 0.00074
# Epoch 71/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.4424e-04 - val_loss: 7.6142e-04
#
# Epoch 00071: val_loss did not improve from 0.00074
# Epoch 72/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.3570e-04 - val_loss: 7.6945e-04
#
# Epoch 00072: val_loss did not improve from 0.00074
# Epoch 73/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.3797e-04 - val_loss: 7.6569e-04
#
# Epoch 00073: val_loss did not improve from 0.00074
# Epoch 74/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.3314e-04 - val_loss: 7.9636e-04
#
# Epoch 00074: val_loss did not improve from 0.00074
# Epoch 75/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.3084e-04 - val_loss: 7.6711e-04
#
# Epoch 00075: val_loss did not improve from 0.00074
# Epoch 76/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.3227e-04 - val_loss: 7.7570e-04
#
# Epoch 00076: val_loss did not improve from 0.00074
# Epoch 77/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.3047e-04 - val_loss: 7.6647e-04
#
# Epoch 00077: val_loss did not improve from 0.00074
# Epoch 78/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.2668e-04 - val_loss: 7.5028e-04
#
# Epoch 00078: val_loss did not improve from 0.00074
# Epoch 79/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.3274e-04 - val_loss: 7.8722e-04
#
# Epoch 00079: val_loss did not improve from 0.00074
# Epoch 80/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.2517e-04 - val_loss: 7.4716e-04
#
# Epoch 00080: val_loss did not improve from 0.00074
# Epoch 81/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.3018e-04 - val_loss: 7.6945e-04
#
# Epoch 00081: val_loss did not improve from 0.00074
# Epoch 82/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.2669e-04 - val_loss: 7.9571e-04
#
# Epoch 00082: val_loss did not improve from 0.00074
# Epoch 83/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.2431e-04 - val_loss: 7.5981e-04
#
# Epoch 00083: val_loss did not improve from 0.00074
# Epoch 84/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.3070e-04 - val_loss: 8.1691e-04
#
# Epoch 00084: val_loss did not improve from 0.00074
# Epoch 85/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.2331e-04 - val_loss: 7.6826e-04
#
# Epoch 00085: val_loss did not improve from 0.00074
# Epoch 86/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.1892e-04 - val_loss: 7.8844e-04
#
# Epoch 00086: val_loss did not improve from 0.00074
# Epoch 87/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.1784e-04 - val_loss: 7.6790e-04
#
# Epoch 00087: val_loss did not improve from 0.00074
# Epoch 88/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.1887e-04 - val_loss: 7.6424e-04
#
# Epoch 00088: val_loss did not improve from 0.00074
# Epoch 89/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.1888e-04 - val_loss: 7.6606e-04
#
# Epoch 00089: val_loss did not improve from 0.00074
# Epoch 90/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.1743e-04 - val_loss: 7.5690e-04
#
# Epoch 00090: val_loss did not improve from 0.00074
# Epoch 91/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.1757e-04 - val_loss: 7.5181e-04
#
# Epoch 00091: val_loss did not improve from 0.00074
# Epoch 92/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.1241e-04 - val_loss: 7.7893e-04
#
# Epoch 00092: val_loss did not improve from 0.00074
# Epoch 93/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.1651e-04 - val_loss: 7.5256e-04
#
# Epoch 00093: val_loss did not improve from 0.00074
# Epoch 94/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.1342e-04 - val_loss: 7.4949e-04
#
# Epoch 00094: val_loss did not improve from 0.00074
# Epoch 95/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.1319e-04 - val_loss: 7.8782e-04
#
# Epoch 00095: val_loss did not improve from 0.00074
# Epoch 96/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.1028e-04 - val_loss: 7.8257e-04
#
# Epoch 00096: val_loss did not improve from 0.00074
# Epoch 97/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.1165e-04 - val_loss: 7.8100e-04
#
# Epoch 00097: val_loss did not improve from 0.00074
# Epoch 98/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.1108e-04 - val_loss: 7.9015e-04
#
# Epoch 00098: val_loss did not improve from 0.00074
# Epoch 99/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.1091e-04 - val_loss: 7.5987e-04
#
# Epoch 00099: val_loss did not improve from 0.00074
# Epoch 100/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.1253e-04 - val_loss: 7.7474e-04
#
# Epoch 00100: val_loss did not improve from 0.00074
# Epoch 101/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.0899e-04 - val_loss: 7.6462e-04
#
# Epoch 00101: val_loss did not improve from 0.00074
# Epoch 102/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.0578e-04 - val_loss: 7.5806e-04
#
# Epoch 00102: val_loss did not improve from 0.00074
# Epoch 103/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.1008e-04 - val_loss: 8.0920e-04
#
# Epoch 00103: val_loss did not improve from 0.00074
# Epoch 104/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.0695e-04 - val_loss: 7.5037e-04
#
# Epoch 00104: val_loss did not improve from 0.00074
# Epoch 105/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.0720e-04 - val_loss: 7.8053e-04
#
# Epoch 00105: val_loss did not improve from 0.00074
# Epoch 106/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.0498e-04 - val_loss: 7.6826e-04
#
# Epoch 00106: val_loss did not improve from 0.00074
# Epoch 107/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.0197e-04 - val_loss: 7.5763e-04
#
# Epoch 00107: val_loss did not improve from 0.00074
# Epoch 108/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.0450e-04 - val_loss: 7.7254e-04
#
# Epoch 00108: val_loss did not improve from 0.00074
# Epoch 109/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.0493e-04 - val_loss: 7.5658e-04
#
# Epoch 00109: val_loss did not improve from 0.00074
# Epoch 110/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.0342e-04 - val_loss: 7.5931e-04
#
# Epoch 00110: val_loss did not improve from 0.00074
# Epoch 111/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.0421e-04 - val_loss: 7.8612e-04
#
# Epoch 00111: val_loss did not improve from 0.00074
# Epoch 112/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.0375e-04 - val_loss: 8.0953e-04
#
# Epoch 00112: val_loss did not improve from 0.00074
# Epoch 113/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 1.0481e-04 - val_loss: 7.9408e-04
#
# Epoch 00113: val_loss did not improve from 0.00074
# Epoch 114/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 9.9672e-05 - val_loss: 7.8584e-04
#
# Epoch 00114: val_loss did not improve from 0.00074
# Epoch 115/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 9.5400e-05 - val_loss: 7.5771e-04
#
# Epoch 00115: val_loss did not improve from 0.00074
# Epoch 116/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 9.4205e-05 - val_loss: 7.9886e-04
#
# Epoch 00116: val_loss did not improve from 0.00074
# Epoch 117/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 9.4234e-05 - val_loss: 8.1524e-04
#
# Epoch 00117: val_loss did not improve from 0.00074
# Epoch 118/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 9.7263e-05 - val_loss: 7.9122e-04
#
# Epoch 00118: val_loss did not improve from 0.00074
# Epoch 119/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.4981e-05 - val_loss: 7.5304e-04
#
# Epoch 00119: val_loss did not improve from 0.00074
# Epoch 120/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.7079e-05 - val_loss: 7.7529e-04
#
# Epoch 00120: val_loss did not improve from 0.00074
# Epoch 121/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.7394e-05 - val_loss: 7.9165e-04
#
# Epoch 00121: val_loss did not improve from 0.00074
# Epoch 122/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.8160e-05 - val_loss: 7.5242e-04
#
# Epoch 00122: val_loss did not improve from 0.00074
# Epoch 123/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.6833e-05 - val_loss: 7.7437e-04
#
# Epoch 00123: val_loss did not improve from 0.00074
# Epoch 124/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.5047e-05 - val_loss: 7.9467e-04
#
# Epoch 00124: val_loss did not improve from 0.00074
# Epoch 125/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.1545e-05 - val_loss: 8.3513e-04
#
# Epoch 00125: val_loss did not improve from 0.00074
# Epoch 126/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.4493e-05 - val_loss: 7.8124e-04
#
# Epoch 00126: val_loss did not improve from 0.00074
# Epoch 127/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.2357e-05 - val_loss: 7.9509e-04
#
# Epoch 00127: val_loss did not improve from 0.00074
# Epoch 128/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.2581e-05 - val_loss: 8.0120e-04
#
# Epoch 00128: val_loss did not improve from 0.00074
# Epoch 129/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 9.0692e-05 - val_loss: 7.5484e-04
#
# Epoch 00129: val_loss did not improve from 0.00074
# Epoch 130/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 8.9766e-05 - val_loss: 7.7668e-04
#
# Epoch 00130: val_loss did not improve from 0.00074
# Epoch 131/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.9466e-05 - val_loss: 7.6913e-04
#
# Epoch 00131: val_loss did not improve from 0.00074
# Epoch 132/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.1599e-05 - val_loss: 7.9418e-04
#
# Epoch 00132: val_loss did not improve from 0.00074
# Epoch 133/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.0968e-05 - val_loss: 7.7402e-04
#
# Epoch 00133: val_loss did not improve from 0.00074
# Epoch 134/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.5802e-05 - val_loss: 7.7388e-04
#
# Epoch 00134: val_loss did not improve from 0.00074
# Epoch 135/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.7474e-05 - val_loss: 7.6534e-04
#
# Epoch 00135: val_loss did not improve from 0.00074
# Epoch 136/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.7841e-05 - val_loss: 7.9683e-04
#
# Epoch 00136: val_loss did not improve from 0.00074
# Epoch 137/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 8.6931e-05 - val_loss: 7.7302e-04
#
# Epoch 00137: val_loss did not improve from 0.00074
# Epoch 138/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.7281e-05 - val_loss: 8.1357e-04
#
# Epoch 00138: val_loss did not improve from 0.00074
# Epoch 139/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.5318e-05 - val_loss: 7.6200e-04
#
# Epoch 00139: val_loss did not improve from 0.00074
# Epoch 140/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.5168e-05 - val_loss: 7.5839e-04
#
# Epoch 00140: val_loss did not improve from 0.00074
# Epoch 141/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.4752e-05 - val_loss: 7.8261e-04
#
# Epoch 00141: val_loss did not improve from 0.00074
# Epoch 142/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.2372e-05 - val_loss: 7.6966e-04
#
# Epoch 00142: val_loss did not improve from 0.00074
# Epoch 143/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.2683e-05 - val_loss: 7.7251e-04
#
# Epoch 00143: val_loss did not improve from 0.00074
# Epoch 144/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.1507e-05 - val_loss: 7.6968e-04
#
# Epoch 00144: val_loss did not improve from 0.00074
# Epoch 145/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 8.1750e-05 - val_loss: 7.8685e-04
#
# Epoch 00145: val_loss did not improve from 0.00074
# Epoch 146/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 8.2609e-05 - val_loss: 8.0584e-04
#
# Epoch 00146: val_loss did not improve from 0.00074
# Epoch 147/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 8.1890e-05 - val_loss: 7.3940e-04
#
# Epoch 00147: val_loss did not improve from 0.00074
# Epoch 148/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 8.2088e-05 - val_loss: 7.8830e-04
#
# Epoch 00148: val_loss did not improve from 0.00074
# Epoch 149/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 8.1504e-05 - val_loss: 7.7845e-04
#
# Epoch 00149: val_loss did not improve from 0.00074
# Epoch 150/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 8.2275e-05 - val_loss: 7.5747e-04
#
# Epoch 00150: val_loss did not improve from 0.00074

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# Function for flipping(label, img)
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # picture flipping
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
    
    # key point flipping
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
        
    # label adjustment
    new_label = np.copy(new_points)
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # original img
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # flipped img

# %%
# Flip the whlole data
aug_imgs_train = []
aug_points_train = []

for i in range(imgs_train.shape[0]):
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    #append original data
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    #append flipped data
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 
    
# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 0.0038 - val_loss: 0.0020
#
# Epoch 00001: val_loss improved from inf to 0.00196, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 0.0012 - val_loss: 0.0020
#
# Epoch 00002: val_loss did not improve from 0.00196
# Epoch 3/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00196 to 0.00182, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.6119e-04 - val_loss: 0.0016
#
# Epoch 00004: val_loss improved from 0.00182 to 0.00156, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 6.8292e-04 - val_loss: 0.0012
#
# Epoch 00005: val_loss improved from 0.00156 to 0.00124, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 5.6505e-04 - val_loss: 0.0011
#
# Epoch 00006: val_loss improved from 0.00124 to 0.00109, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 5.0181e-04 - val_loss: 0.0010
#
# Epoch 00007: val_loss improved from 0.00109 to 0.00101, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 4.4894e-04 - val_loss: 9.5029e-04
#
# Epoch 00008: val_loss improved from 0.00101 to 0.00095, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 4.1537e-04 - val_loss: 8.8159e-04
#
# Epoch 00009: val_loss improved from 0.00095 to 0.00088, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 3.8742e-04 - val_loss: 8.4554e-04
#
# Epoch 00010: val_loss improved from 0.00088 to 0.00085, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 3.5839e-04 - val_loss: 8.3427e-04
#
# Epoch 00011: val_loss improved from 0.00085 to 0.00083, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 3.3717e-04 - val_loss: 7.8738e-04
#
# Epoch 00012: val_loss improved from 0.00083 to 0.00079, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 3.2619e-04 - val_loss: 8.2446e-04
#
# Epoch 00013: val_loss did not improve from 0.00079
# Epoch 14/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 3.0491e-04 - val_loss: 7.4554e-04
#
# Epoch 00014: val_loss improved from 0.00079 to 0.00075, saving model to best_weights_augment.h5
# Epoch 15/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 2.9002e-04 - val_loss: 7.7412e-04
#
# Epoch 00015: val_loss did not improve from 0.00075
# Epoch 16/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 2.8247e-04 - val_loss: 7.2901e-04
#
# Epoch 00016: val_loss improved from 0.00075 to 0.00073, saving model to best_weights_augment.h5
# Epoch 17/150
# 3424/3424 [==============================] - 9s 2ms/step - loss: 2.7303e-04 - val_loss: 7.1799e-04
#
# Epoch 00017: val_loss improved from 0.00073 to 0.00072, saving model to best_weights_augment.h5
# Epoch 18/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 2.6365e-04 - val_loss: 7.1130e-04
#
# Epoch 00018: val_loss improved from 0.00072 to 0.00071, saving model to best_weights_augment.h5
# Epoch 19/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 2.4974e-04 - val_loss: 7.7974e-04
#
# Epoch 00019: val_loss did not improve from 0.00071
# Epoch 20/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 2.4744e-04 - val_loss: 6.7452e-04
#
# Epoch 00020: val_loss improved from 0.00071 to 0.00067, saving model to best_weights_augment.h5
# Epoch 21/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 2.3568e-04 - val_loss: 6.8998e-04
#
# Epoch 00021: val_loss did not improve from 0.00067
# Epoch 22/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 2.3478e-04 - val_loss: 6.8711e-04
#
# Epoch 00022: val_loss did not improve from 0.00067
# Epoch 23/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 2.2513e-04 - val_loss: 6.7244e-04
#
# Epoch 00023: val_loss improved from 0.00067 to 0.00067, saving model to best_weights_augment.h5
# Epoch 24/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 2.1517e-04 - val_loss: 6.7579e-04
#
# Epoch 00024: val_loss did not improve from 0.00067
# Epoch 25/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 2.1853e-04 - val_loss: 6.7462e-04
#
# Epoch 00025: val_loss did not improve from 0.00067
# Epoch 26/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 2.0720e-04 - val_loss: 6.9784e-04
#
# Epoch 00026: val_loss did not improve from 0.00067
# Epoch 27/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 2.0036e-04 - val_loss: 6.6676e-04
#
# Epoch 00027: val_loss improved from 0.00067 to 0.00067, saving model to best_weights_augment.h5
# Epoch 28/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 2.0024e-04 - val_loss: 6.5538e-04
#
# Epoch 00028: val_loss improved from 0.00067 to 0.00066, saving model to best_weights_augment.h5
# Epoch 29/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 2.0452e-04 - val_loss: 6.6008e-04
#
# Epoch 00029: val_loss did not improve from 0.00066
# Epoch 30/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.9375e-04 - val_loss: 6.6066e-04
#
# Epoch 00030: val_loss did not improve from 0.00066
# Epoch 31/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.8689e-04 - val_loss: 7.1446e-04
#
# Epoch 00031: val_loss did not improve from 0.00066
# Epoch 32/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.8972e-04 - val_loss: 6.5691e-04
#
# Epoch 00032: val_loss did not improve from 0.00066
# Epoch 33/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 1.8527e-04 - val_loss: 6.5585e-04
#
# Epoch 00033: val_loss did not improve from 0.00066
# Epoch 34/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 1.7761e-04 - val_loss: 6.4109e-04
#
# Epoch 00034: val_loss improved from 0.00066 to 0.00064, saving model to best_weights_augment.h5
# Epoch 35/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.7480e-04 - val_loss: 6.4288e-04
#
# Epoch 00035: val_loss did not improve from 0.00064
# Epoch 36/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.7492e-04 - val_loss: 6.4517e-04
#
# Epoch 00036: val_loss did not improve from 0.00064
# Epoch 37/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.6787e-04 - val_loss: 6.7683e-04
#
# Epoch 00037: val_loss did not improve from 0.00064
# Epoch 38/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.7109e-04 - val_loss: 6.9811e-04
#
# Epoch 00038: val_loss did not improve from 0.00064
# Epoch 39/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 1.6733e-04 - val_loss: 6.5139e-04
#
# Epoch 00039: val_loss did not improve from 0.00064
# Epoch 40/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.6554e-04 - val_loss: 6.4339e-04
#
# Epoch 00040: val_loss did not improve from 0.00064
# Epoch 41/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 1.5938e-04 - val_loss: 6.3309e-04
#
# Epoch 00041: val_loss improved from 0.00064 to 0.00063, saving model to best_weights_augment.h5
# Epoch 42/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.5665e-04 - val_loss: 6.5827e-04
#
# Epoch 00042: val_loss did not improve from 0.00063
# Epoch 43/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.5602e-04 - val_loss: 7.0919e-04
#
# Epoch 00043: val_loss did not improve from 0.00063
# Epoch 44/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.5299e-04 - val_loss: 6.3607e-04
#
# Epoch 00044: val_loss did not improve from 0.00063
# Epoch 45/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 1.4845e-04 - val_loss: 6.5804e-04
#
# Epoch 00045: val_loss did not improve from 0.00063
# Epoch 46/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.4840e-04 - val_loss: 6.4190e-04
#
# Epoch 00046: val_loss did not improve from 0.00063
# Epoch 47/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 1.4546e-04 - val_loss: 6.7020e-04
#
# Epoch 00047: val_loss did not improve from 0.00063
# Epoch 48/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 1.4385e-04 - val_loss: 6.4807e-04
#
# Epoch 00048: val_loss did not improve from 0.00063
# Epoch 49/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.4004e-04 - val_loss: 6.3064e-04
#
# Epoch 00049: val_loss improved from 0.00063 to 0.00063, saving model to best_weights_augment.h5
# Epoch 50/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.3902e-04 - val_loss: 6.6288e-04
#
# Epoch 00050: val_loss did not improve from 0.00063
# Epoch 51/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.4069e-04 - val_loss: 6.9701e-04
#
# Epoch 00051: val_loss did not improve from 0.00063
# Epoch 52/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.3601e-04 - val_loss: 6.5285e-04
#
# Epoch 00052: val_loss did not improve from 0.00063
# Epoch 53/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.3454e-04 - val_loss: 6.3290e-04
#
# Epoch 00053: val_loss did not improve from 0.00063
# Epoch 54/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.3427e-04 - val_loss: 6.3148e-04
#
# Epoch 00054: val_loss did not improve from 0.00063
# Epoch 55/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.3607e-04 - val_loss: 6.8922e-04
#
# Epoch 00055: val_loss did not improve from 0.00063
# Epoch 56/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.3254e-04 - val_loss: 6.4568e-04
#
# Epoch 00056: val_loss did not improve from 0.00063
# Epoch 57/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.2747e-04 - val_loss: 6.4699e-04
#
# Epoch 00057: val_loss did not improve from 0.00063
# Epoch 58/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.2507e-04 - val_loss: 6.5395e-04
#
# Epoch 00058: val_loss did not improve from 0.00063
# Epoch 59/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.2376e-04 - val_loss: 6.9003e-04
#
# Epoch 00059: val_loss did not improve from 0.00063
# Epoch 60/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.2706e-04 - val_loss: 6.5600e-04
#
# Epoch 00060: val_loss did not improve from 0.00063
# Epoch 61/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.2215e-04 - val_loss: 6.4766e-04
#
# Epoch 00061: val_loss did not improve from 0.00063
# Epoch 62/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.2132e-04 - val_loss: 6.5863e-04
#
# Epoch 00062: val_loss did not improve from 0.00063
# Epoch 63/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.2108e-04 - val_loss: 6.6897e-04
#
# Epoch 00063: val_loss did not improve from 0.00063
# Epoch 64/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.1886e-04 - val_loss: 6.1151e-04
#
# Epoch 00064: val_loss improved from 0.00063 to 0.00061, saving model to best_weights_augment.h5
# Epoch 65/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.1683e-04 - val_loss: 6.3028e-04
#
# Epoch 00065: val_loss did not improve from 0.00061
# Epoch 66/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.1493e-04 - val_loss: 6.2210e-04
#
# Epoch 00066: val_loss did not improve from 0.00061
# Epoch 67/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 1.1709e-04 - val_loss: 6.4609e-04
#
# Epoch 00067: val_loss did not improve from 0.00061
# Epoch 68/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.1462e-04 - val_loss: 6.2278e-04
#
# Epoch 00068: val_loss did not improve from 0.00061
# Epoch 69/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.1332e-04 - val_loss: 6.3316e-04
#
# Epoch 00069: val_loss did not improve from 0.00061
# Epoch 70/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.1156e-04 - val_loss: 6.1901e-04
#
# Epoch 00070: val_loss did not improve from 0.00061
# Epoch 71/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.1201e-04 - val_loss: 6.6864e-04
#
# Epoch 00071: val_loss did not improve from 0.00061
# Epoch 72/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.0903e-04 - val_loss: 6.4691e-04
#
# Epoch 00072: val_loss did not improve from 0.00061
# Epoch 73/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.1035e-04 - val_loss: 6.6453e-04
#
# Epoch 00073: val_loss did not improve from 0.00061
# Epoch 74/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.0765e-04 - val_loss: 6.3538e-04
#
# Epoch 00074: val_loss did not improve from 0.00061
# Epoch 75/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.0885e-04 - val_loss: 6.4884e-04
#
# Epoch 00075: val_loss did not improve from 0.00061
# Epoch 76/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.0715e-04 - val_loss: 6.6025e-04
#
# Epoch 00076: val_loss did not improve from 0.00061
# Epoch 77/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.0601e-04 - val_loss: 6.2691e-04
#
# Epoch 00077: val_loss did not improve from 0.00061
# Epoch 78/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.0747e-04 - val_loss: 6.1223e-04
#
# Epoch 00078: val_loss did not improve from 0.00061
# Epoch 79/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.0469e-04 - val_loss: 6.3315e-04
#
# Epoch 00079: val_loss did not improve from 0.00061
# Epoch 80/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.0260e-04 - val_loss: 6.4264e-04
#
# Epoch 00080: val_loss did not improve from 0.00061
# Epoch 81/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.0421e-04 - val_loss: 6.5598e-04
#
# Epoch 00081: val_loss did not improve from 0.00061
# Epoch 82/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.0137e-04 - val_loss: 6.2083e-04
#
# Epoch 00082: val_loss did not improve from 0.00061
# Epoch 83/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.0220e-04 - val_loss: 6.1884e-04
#
# Epoch 00083: val_loss did not improve from 0.00061
# Epoch 84/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.0243e-04 - val_loss: 6.0333e-04
#
# Epoch 00084: val_loss improved from 0.00061 to 0.00060, saving model to best_weights_augment.h5
# Epoch 85/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.0035e-04 - val_loss: 6.3551e-04
#
# Epoch 00085: val_loss did not improve from 0.00060
# Epoch 86/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 1.0026e-04 - val_loss: 6.4202e-04
#
# Epoch 00086: val_loss did not improve from 0.00060
# Epoch 87/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 9.9201e-05 - val_loss: 6.4030e-04
#
# Epoch 00087: val_loss did not improve from 0.00060
# Epoch 88/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.0044e-04 - val_loss: 6.4057e-04
#
# Epoch 00088: val_loss did not improve from 0.00060
# Epoch 89/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.7368e-05 - val_loss: 6.4245e-04
#
# Epoch 00089: val_loss did not improve from 0.00060
# Epoch 90/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.8821e-05 - val_loss: 6.2562e-04
#
# Epoch 00090: val_loss did not improve from 0.00060
# Epoch 91/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.8386e-05 - val_loss: 6.3453e-04
#
# Epoch 00091: val_loss did not improve from 0.00060
# Epoch 92/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 9.6094e-05 - val_loss: 6.4982e-04
#
# Epoch 00092: val_loss did not improve from 0.00060
# Epoch 93/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.4661e-05 - val_loss: 6.3486e-04
#
# Epoch 00093: val_loss did not improve from 0.00060
# Epoch 94/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.3998e-05 - val_loss: 6.4426e-04
#
# Epoch 00094: val_loss did not improve from 0.00060
# Epoch 95/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 9.5147e-05 - val_loss: 6.3063e-04
#
# Epoch 00095: val_loss did not improve from 0.00060
# Epoch 96/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 9.3654e-05 - val_loss: 6.7057e-04
#
# Epoch 00096: val_loss did not improve from 0.00060
# Epoch 97/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 9.4060e-05 - val_loss: 6.2571e-04
#
# Epoch 00097: val_loss did not improve from 0.00060
# Epoch 98/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 9.3842e-05 - val_loss: 6.2432e-04
#
# Epoch 00098: val_loss did not improve from 0.00060
# Epoch 99/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 9.3150e-05 - val_loss: 6.5023e-04
#
# Epoch 00099: val_loss did not improve from 0.00060
# Epoch 100/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 9.1077e-05 - val_loss: 6.3480e-04
#
# Epoch 00100: val_loss did not improve from 0.00060
# Epoch 101/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.2392e-05 - val_loss: 6.2388e-04
#
# Epoch 00101: val_loss did not improve from 0.00060
# Epoch 102/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.9524e-05 - val_loss: 6.2995e-04
#
# Epoch 00102: val_loss did not improve from 0.00060
# Epoch 103/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 9.0676e-05 - val_loss: 6.3963e-04
#
# Epoch 00103: val_loss did not improve from 0.00060
# Epoch 104/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 9.4805e-05 - val_loss: 6.2295e-04
#
# Epoch 00104: val_loss did not improve from 0.00060
# Epoch 105/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 9.2781e-05 - val_loss: 6.1533e-04
#
# Epoch 00105: val_loss did not improve from 0.00060
# Epoch 106/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 9.0333e-05 - val_loss: 6.3354e-04
#
# Epoch 00106: val_loss did not improve from 0.00060
# Epoch 107/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.9694e-05 - val_loss: 6.4463e-04
#
# Epoch 00107: val_loss did not improve from 0.00060
# Epoch 108/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 9.0041e-05 - val_loss: 6.3047e-04
#
# Epoch 00108: val_loss did not improve from 0.00060
# Epoch 109/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.0979e-05 - val_loss: 6.2211e-04
#
# Epoch 00109: val_loss did not improve from 0.00060
# Epoch 110/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.7694e-05 - val_loss: 6.1053e-04
#
# Epoch 00110: val_loss did not improve from 0.00060
# Epoch 111/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.8759e-05 - val_loss: 6.4334e-04
#
# Epoch 00111: val_loss did not improve from 0.00060
# Epoch 112/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.7225e-05 - val_loss: 6.3252e-04
#
# Epoch 00112: val_loss did not improve from 0.00060
# Epoch 113/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.6730e-05 - val_loss: 6.3619e-04
#
# Epoch 00113: val_loss did not improve from 0.00060
# Epoch 114/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.7198e-05 - val_loss: 6.2401e-04
#
# Epoch 00114: val_loss did not improve from 0.00060
# Epoch 115/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.7774e-05 - val_loss: 6.3437e-04
#
# Epoch 00115: val_loss did not improve from 0.00060
# Epoch 116/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.5148e-05 - val_loss: 6.5832e-04
#
# Epoch 00116: val_loss did not improve from 0.00060
# Epoch 117/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.6547e-05 - val_loss: 6.2008e-04
#
# Epoch 00117: val_loss did not improve from 0.00060
# Epoch 118/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.4930e-05 - val_loss: 6.2948e-04
#
# Epoch 00118: val_loss did not improve from 0.00060
# Epoch 119/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.5723e-05 - val_loss: 6.4404e-04
#
# Epoch 00119: val_loss did not improve from 0.00060
# Epoch 120/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.3403e-05 - val_loss: 6.2667e-04
#
# Epoch 00120: val_loss did not improve from 0.00060
# Epoch 121/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.5006e-05 - val_loss: 6.2014e-04
#
# Epoch 00121: val_loss did not improve from 0.00060
# Epoch 122/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.4103e-05 - val_loss: 6.1660e-04
#
# Epoch 00122: val_loss did not improve from 0.00060
# Epoch 123/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.5767e-05 - val_loss: 6.4650e-04
#
# Epoch 00123: val_loss did not improve from 0.00060
# Epoch 124/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.2554e-05 - val_loss: 6.3076e-04
#
# Epoch 00124: val_loss did not improve from 0.00060
# Epoch 125/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.4366e-05 - val_loss: 6.3728e-04
#
# Epoch 00125: val_loss did not improve from 0.00060
# Epoch 126/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.2858e-05 - val_loss: 6.3636e-04
#
# Epoch 00126: val_loss did not improve from 0.00060
# Epoch 127/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.3273e-05 - val_loss: 6.3874e-04
#
# Epoch 00127: val_loss did not improve from 0.00060
# Epoch 128/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.1590e-05 - val_loss: 6.2871e-04
#
# Epoch 00128: val_loss did not improve from 0.00060
# Epoch 129/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.2316e-05 - val_loss: 6.2407e-04
#
# Epoch 00129: val_loss did not improve from 0.00060
# Epoch 130/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.1056e-05 - val_loss: 6.3651e-04
#
# Epoch 00130: val_loss did not improve from 0.00060
# Epoch 131/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.2175e-05 - val_loss: 6.2802e-04
#
# Epoch 00131: val_loss did not improve from 0.00060
# Epoch 132/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.3140e-05 - val_loss: 6.4900e-04
#
# Epoch 00132: val_loss did not improve from 0.00060
# Epoch 133/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.1528e-05 - val_loss: 6.2891e-04
#
# Epoch 00133: val_loss did not improve from 0.00060
# Epoch 134/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.1688e-05 - val_loss: 6.2082e-04
#
# Epoch 00134: val_loss did not improve from 0.00060
# Epoch 135/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 7.9504e-05 - val_loss: 6.4831e-04
#
# Epoch 00135: val_loss did not improve from 0.00060
# Epoch 136/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.1907e-05 - val_loss: 6.4482e-04
#
# Epoch 00136: val_loss did not improve from 0.00060
# Epoch 137/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.0478e-05 - val_loss: 6.4317e-04
#
# Epoch 00137: val_loss did not improve from 0.00060
# Epoch 138/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 7.8259e-05 - val_loss: 6.2464e-04
#
# Epoch 00138: val_loss did not improve from 0.00060
# Epoch 139/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 7.9750e-05 - val_loss: 6.5024e-04
#
# Epoch 00139: val_loss did not improve from 0.00060
# Epoch 140/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 7.9727e-05 - val_loss: 6.2699e-04
#
# Epoch 00140: val_loss did not improve from 0.00060
# Epoch 141/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 7.8932e-05 - val_loss: 6.4969e-04
#
# Epoch 00141: val_loss did not improve from 0.00060
# Epoch 142/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.3667e-05 - val_loss: 6.4961e-04
#
# Epoch 00142: val_loss did not improve from 0.00060
# Epoch 143/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 7.9182e-05 - val_loss: 6.3405e-04
#
# Epoch 00143: val_loss did not improve from 0.00060
# Epoch 144/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 8.0921e-05 - val_loss: 6.2781e-04
#
# Epoch 00144: val_loss did not improve from 0.00060
# Epoch 145/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 7.9981e-05 - val_loss: 6.4007e-04
#
# Epoch 00145: val_loss did not improve from 0.00060
# Epoch 146/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 7.9572e-05 - val_loss: 6.4543e-04
#
# Epoch 00146: val_loss did not improve from 0.00060
# Epoch 147/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 7.7816e-05 - val_loss: 6.3497e-04
#
# Epoch 00147: val_loss did not improve from 0.00060
# Epoch 148/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 7.6663e-05 - val_loss: 6.3243e-04
#
# Epoch 00148: val_loss did not improve from 0.00060
# Epoch 149/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 7.7335e-05 - val_loss: 6.3038e-04
#
# Epoch 00149: val_loss did not improve from 0.00060
# Epoch 150/150
# 3424/3424 [==============================] - 6s 2ms/step - loss: 7.6464e-05 - val_loss: 6.4501e-04
#
# Epoch 00150: val_loss did not improve from 0.00060

# %%
# loss pic
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
